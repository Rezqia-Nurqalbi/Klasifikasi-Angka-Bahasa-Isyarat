# %% [markdown]
# # **DATA TEST ASLI DAN TRAINING MODEL ResNet Tranfer Learning**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import cv2 as cv
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
path = "/content/drive/MyDrive/Skripsi_Dataset/Dataset/Gabungan Train+Val"
test_dir = "/content/drive/MyDrive/Skripsi_Dataset/Dataset/Test_Images"

# %%
key_value = dict()
for i in os.listdir(path):
    key_value[i] = os.listdir(os.path.join(path, i))

df = []
for key in key_value.keys():
    for j in key_value[key]:
        df.append([key, os.path.join(path, key, j)])
df1 = pd.DataFrame(df, columns=('label', 'path'))
print("Total gambar training:", len(df1))
# Out:
# Total gambar training: 1649

# %%
def readimg(path):
    img = cv.imread(path)
    img = cv.resize(img, (224, 224))
    return img

# %%
import multiprocessing
with multiprocessing.Pool(4) as p:
    images = p.map(readimg, df1['path'])

images = np.array(images, dtype='float')
le = preprocessing.LabelEncoder()
y_labels = le.fit_transform(df1['label'])

# %%
key_value_test = dict()
for i in os.listdir(test_dir):
    key_value_test[i] = os.listdir(os.path.join(test_dir, i))

df_test = []
for key in key_value_test.keys():
    for j in key_value_test[key]:
        df_test.append([key, os.path.join(test_dir, key, j)])
df_test = pd.DataFrame(df_test, columns=('label', 'path'))
print("Total gambar test:", len(df_test))
# Out:
# Total gambar test: 413

# %%
with multiprocessing.Pool(4) as p:
    test_images = p.map(readimg, df_test['path'])

test_images = np.array(test_images, dtype='float')
test_labels = le.transform(df_test['label'])

# %%
train_images, val_images, train_labels, val_labels = train_test_split(
    images, y_labels, test_size=0.2, random_state=1
)

# %%
print(f"Jumlah total data training: {len(train_images)}")
print(f"Jumlah total data validation: {len(val_images)}")
print(f"Jumlah total data test: {len(test_images)}")
# Out:
# Jumlah total data training: 1319
# Jumlah total data validation: 330
# Jumlah total data test: 413

# %%
## implementing trensfer learning
base_model = keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# freezing the base model so we donot have to train it again
base_model.trainable = False

model = keras.Sequential([
  base_model,
  keras.layers.GlobalAveragePooling2D(),
  keras.layers.Dense(1024, activation='relu'),
  keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = model.fit(
    train_images, train_labels,
    epochs=50,
    batch_size=32,
    validation_data=(val_images, val_labels),
    shuffle=True
)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 30s 387ms/step - accuracy: 0.4228 - loss: 2.2461 - val_accuracy: 0.7182 - val_loss: 0.7368
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8387 - loss: 0.4783 - val_accuracy: 0.8848 - val_loss: 0.3691
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.9121 - loss: 0.2694 - val_accuracy: 0.8515 - val_loss: 0.5077
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.9483 - loss: 0.1648 - val_accuracy: 0.8848 - val_loss: 0.4147
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.9619 - loss: 0.1244 - val_accuracy: 0.8818 - val_loss: 0.3532
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.9699 - loss: 0.1056 - val_accuracy: 0.8788 - val_loss: 0.3709
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.9855 - loss: 0.0716 - val_accuracy: 0.9242 - val_loss: 0.2701
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9907 - loss: 0.0469 - val_accuracy: 0.9424 - val_loss: 0.2369
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9988 - loss: 0.0331 - val_accuracy: 0.9394 - val_loss: 0.2393
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9971 - loss: 0.0291 - val_accuracy: 0.9394 - val_loss: 0.2373
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9998 - loss: 0.0227 - val_accuracy: 0.9455 - val_loss: 0.2291
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.9965 - loss: 0.0276 - val_accuracy: 0.9212 - val_loss: 0.2707
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.9303 - val_loss: 0.2628
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.9394 - val_loss: 0.2488
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9364 - val_loss: 0.2498
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9394 - val_loss: 0.2507
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9485 - val_loss: 0.2342
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9394 - val_loss: 0.2512
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9394 - val_loss: 0.2481
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9242 - val_loss: 0.2661
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9455 - val_loss: 0.2487
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9485 - val_loss: 0.2408
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9455 - val_loss: 0.2513
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9424 - val_loss: 0.2497
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9455 - val_loss: 0.2501
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9364 - val_loss: 0.2541
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9485 - val_loss: 0.2499
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9515 - val_loss: 0.2561
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9455 - val_loss: 0.2555
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9455 - val_loss: 0.2573
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9485 - val_loss: 0.2658
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9394 - val_loss: 0.2632
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9333 - val_loss: 0.2601
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9364 - val_loss: 0.2648
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9424 - val_loss: 0.2676
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9364 - val_loss: 0.2643
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9455 - val_loss: 0.2627
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9455 - val_loss: 0.2642
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9485 - val_loss: 0.2607
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9424 - val_loss: 0.2729
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9485 - val_loss: 0.2671
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 1.0000 - loss: 9.8370e-04 - val_accuracy: 0.9485 - val_loss: 0.2756
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 1.0000 - loss: 8.8530e-04 - val_accuracy: 0.9545 - val_loss: 0.2655
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 1.0000 - loss: 8.5172e-04 - val_accuracy: 0.9455 - val_loss: 0.2737
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 1.0000 - loss: 9.1285e-04 - val_accuracy: 0.9455 - val_loss: 0.2756
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 1.0000 - loss: 8.1307e-04 - val_accuracy: 0.9455 - val_loss: 0.2736
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 8.0595e-04 - val_accuracy: 0.9485 - val_loss: 0.2703
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 8.2871e-04 - val_accuracy: 0.9485 - val_loss: 0.2748
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 1.0000 - loss: 7.7542e-04 - val_accuracy: 0.9485 - val_loss: 0.2839
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 1.0000 - loss: 8.0350e-04 - val_accuracy: 0.9394 - val_loss: 0.2777

# %%
# ===================== SIMPAN HISTORY KE CSV ============================
# Mengubah history ke DataFrame
hist_df = pd.DataFrame(history.history)

# Menentukan path penyimpanan di Google Drive
csv_path = "/content/drive/MyDrive/Skripsi_Dataset/Csv Training/ResNet50_TL_TrainOri.csv"

# Simpan ke CSV
hist_df.to_csv(csv_path, index=False)

print(f"Hasil training telah disimpan ke: {csv_path}")
# Out:
# Hasil training telah disimpan ke: /content/drive/MyDrive/Skripsi_Dataset/Csv Training/ResNet50_TL_TrainOri.csv

# %%
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 592ms/step

# %%
numer_type = [str(i) for i in range(10)]
fig, ax = plt.subplots(figsize=(7,7))
cm = confusion_matrix(test_labels, predicted_labels)
sns.heatmap(cm, cmap=plt.cm.Blues, annot=True,
            square=True, xticklabels=numer_type,
            yticklabels=numer_type, ax=ax)
ax.set_ylabel('Actual', fontsize=15)
ax.set_xlabel('Predicted', fontsize=15)
ax.set_title('Confusion Matrix', fontsize=20, pad=20)
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.title('Loss vs Epoch')

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.title('Accuracy vs Epoch')
plt.show()

# %%
target_class_names = [str(i) for i in range(10)]
print("\nClassification Report Data Test Asli:")
print(classification_report(test_labels, predicted_labels, target_names=target_class_names, digits=4))
# Out:
# Classification Report Data Test Asli:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        47
#            1     0.9444    0.9714    0.9577        35
#            2     0.9545    0.9767    0.9655        43
#            3     1.0000    1.0000    1.0000        41
#            4     0.9268    0.9048    0.9157        42
#            5     0.9750    0.9750    0.9750        40
#            6     0.8684    0.8919    0.8800        37
#            7     0.9250    0.8409    0.8810        44
#            8     0.8837    0.8636    0.8736        44
#            9     0.9070    0.9750    0.9398        40
#
#     accuracy                         0.9395       413
#    macro avg     0.9385    0.9399    0.9388       413
# weighted avg     0.9395    0.9395    0.9391       413

# %%
from sklearn.metrics import accuracy_score

# Make predictions on the test data
predictions = model.predict(test_images)

# Convert the predictions to the class labels
predicted_labels = np.argmax(predictions, axis=1)

# Compute the accuracy score
accuracy = accuracy_score(test_labels, predicted_labels)

print('Accuracy:', accuracy)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# Accuracy: 0.9394673123486683

# %%
from sklearn.metrics import precision_score

precision = precision_score(test_labels, predicted_labels, average='macro')

print('Precision:', precision)
# Out:
# Precision: 0.9384937894332765

# %%
from sklearn.metrics import recall_score

recall= recall_score(test_labels, predicted_labels, average='macro')

print('Recall:', recall)
# Out:
# Recall: 0.9399372008674334

# %%
from sklearn.metrics import f1_score

f1= f1_score(test_labels, predicted_labels, average='macro')

print('F1-Score:', f1)
# Out:
# F1-Score: 0.9388201006342722

# %%
accuracy = accuracy_score(test_labels, predicted_labels)
precision = precision_score(test_labels, predicted_labels, average='macro')
recall = recall_score(test_labels, predicted_labels, average='macro')
f1 = f1_score(test_labels, predicted_labels, average='macro')

print("\n=== HASIL EVALUASI ===")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-Score : {f1:.4f}")
# Out:
# === HASIL EVALUASI ===
# Accuracy : 0.9395
# Precision: 0.9385
# Recall   : 0.9399
# F1-Score : 0.9388

# %%
model.summary()
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,912,992 (114.11 MB)
#  Trainable params: 2,108,426 (8.04 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
#  Optimizer params: 4,216,854 (16.09 MB)

# %%
# --- Tampilkan Prediksi Benar dan Salah ---
import random

# Buat array indeks prediksi benar dan salah
correct_idx = np.where(predicted_labels == test_labels)[0]
incorrect_idx = np.where(predicted_labels != test_labels)[0]

print(f"Total prediksi benar: {len(correct_idx)}")
print(f"Total prediksi salah: {len(incorrect_idx)}")

# Fungsi bantu untuk menampilkan gambar
def show_images(indices, title):
    plt.figure(figsize=(14, 6))
    for i, idx in enumerate(random.sample(list(indices), min(10, len(indices)))):  # tampilkan 10 contoh acak
        plt.subplot(2, 5, i + 1)
        img = cv.cvtColor(test_images[idx].astype('uint8'), cv.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.title(f"Pred: {le.classes_[predicted_labels[idx]]}\nTrue: {le.classes_[test_labels[idx]]}")
        plt.axis('off')
    plt.suptitle(title, fontsize=16)
    plt.show()

# Tampilkan gambar prediksi benar
show_images(correct_idx, "Contoh Prediksi Benar")

# Tampilkan gambar prediksi salah
show_images(incorrect_idx, "Contoh Prediksi Salah")
# Out:
# Total prediksi benar: 388
# Total prediksi salah: 25

# %%
model.save('/content/drive/MyDrive/Skripsi_Dataset/Model Baru/ResNet50_TL_TrainOri.keras')

print("Model ResNet50 telah berhasil disimpan dengan nama: ResNet50_TL_TrainOri.keras")
# Out:
# Model ResNet50 telah berhasil disimpan dengan nama: ResNet50_TL_TrainOri.keras

# %%
model.save('/content/drive/MyDrive/Skripsi_Dataset/Model Baru/ResNet50_TL_TrainOri.h5')

print("Model ResNet50 telah berhasil disimpan dengan nama: ResNet50_TL_TrainOri.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model ResNet50 telah berhasil disimpan dengan nama: ResNet50_TL_TrainOri.h5

# %% [markdown]
# # **DATA TEST AUGMENTASI**

# %%
import os
import numpy as np
import cv2 as cv
import pandas as pd
import tensorflow as tf
from sklearn import preprocessing
from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, precision_score, recall_score, f1_score
)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model_path = "/content/drive/MyDrive/Skripsi_Dataset/Model Baru/ResNet50_TL_TrainOri.keras"
test_new_dir = "/content/drive/MyDrive/Skripsi_Dataset/Dataset_Augmented/Data_Test"

# %%
print("Memuat model yang sudah dilatih...")
model = tf.keras.models.load_model(model_path)
print("Model berhasil dimuat!")
# Out:
# Memuat model yang sudah dilatih...
# Model berhasil dimuat!

# %%
key_value_test_new = dict()
for i in os.listdir(test_new_dir):
    key_value_test_new[i] = os.listdir(os.path.join(test_new_dir, i))

# %%
df_test_new = []
for key in key_value_test_new.keys():
    for j in key_value_test_new[key]:
        df_test_new.append([key, os.path.join(test_new_dir, key, j)])
df_test_new = pd.DataFrame(df_test_new, columns=('label', 'path'))
print("Total gambar test baru:", len(df_test_new))
# Out:
# Total gambar test baru: 413

# %%
def readimg(path):
    img = cv.imread(path)
    img = cv.resize(img, (224, 224))
    return img

# %%
import multiprocessing
with multiprocessing.Pool(4) as p:
    test_images_new = p.map(readimg, df_test_new['path'])

test_images_new = np.array(test_images_new, dtype='float')

# %%
le = preprocessing.LabelEncoder()
le.fit(df_test_new['label'])
test_labels_new = le.transform(df_test_new['label'])

# %%
print("\n Melakukan prediksi pada data test augmentasi...")
predictions_new = model.predict(test_images_new)
predicted_labels_new = np.argmax(predictions_new, axis=1)
# Out:
#  Melakukan prediksi pada data test augmentasi...
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 382ms/step

# %%
accuracy = accuracy_score(test_labels_new, predicted_labels_new)
precision = precision_score(test_labels_new, predicted_labels_new, average='macro')
recall = recall_score(test_labels_new, predicted_labels_new, average='macro')
f1 = f1_score(test_labels_new, predicted_labels_new, average='macro')

# %%
print("\n=== HASIL EVALUASI DATA TEST AUGMENTASI ===")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-Score : {f1:.4f}")
# Out:
# === HASIL EVALUASI DATA TEST AUGMENTASI ===
# Accuracy : 0.7869
# Precision: 0.8300
# Recall   : 0.7880
# F1-Score : 0.7865

# %%
target_class_names = le.classes_
print("\nClassification Report:")
print(classification_report(test_labels_new, predicted_labels_new, target_names=target_class_names, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9400    1.0000    0.9691        47
#            1     0.9655    0.8000    0.8750        35
#            2     0.8462    0.7674    0.8049        43
#            3     0.6786    0.9268    0.7835        41
#            4     0.8571    0.8571    0.8571        42
#            5     0.9737    0.9250    0.9487        40
#            6     0.9600    0.6486    0.7742        37
#            7     0.7778    0.4773    0.5915        44
#            8     0.8077    0.4773    0.6000        44
#            9     0.4938    1.0000    0.6612        40
#
#     accuracy                         0.7869       413
#    macro avg     0.8300    0.7880    0.7865       413
# weighted avg     0.8285    0.7869    0.7854       413

# %%
plt.figure(figsize=(7,7))
cm = confusion_matrix(test_labels_new, predicted_labels_new)
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g',
            xticklabels=target_class_names,
            yticklabels=target_class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Data Test Augmentasi")
plt.show()

# %%
import random

correct_idx = np.where(predicted_labels_new == test_labels_new)[0]
incorrect_idx = np.where(predicted_labels_new != test_labels_new)[0]

def show_images(indices, title):
    plt.figure(figsize=(14, 6))
    for i, idx in enumerate(random.sample(list(indices), min(10, len(indices)))):
        plt.subplot(2, 5, i + 1)
        img = cv.cvtColor(test_images_new[idx].astype('uint8'), cv.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.title(f"Pred: {target_class_names[predicted_labels_new[idx]]}\nTrue: {target_class_names[test_labels_new[idx]]}")
        plt.axis('off')
    plt.suptitle(title, fontsize=16)
    plt.show()

show_images(correct_idx, "Contoh Prediksi Benar (Data Test Asli)")
show_images(incorrect_idx, "Contoh Prediksi Salah (Data Test Asli)")

# %% [markdown]
# # **DATA TEST GABUNGAN**

# %%
import os
import numpy as np
import cv2 as cv
import pandas as pd
import tensorflow as tf
from sklearn import preprocessing
from sklearn.metrics import (
    confusion_matrix, classification_report,
    accuracy_score, precision_score, recall_score, f1_score
)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model_path = "/content/drive/MyDrive/Skripsi_Dataset/Model Baru/ResNet50_TL_TrainOri.keras"
test_new_dir = "/content/drive/MyDrive/Skripsi_Dataset/Data Test Gabungan"

# %%
print("Memuat model yang sudah dilatih...")
model = tf.keras.models.load_model(model_path)
print("Model berhasil dimuat!")
# Out:
# Memuat model yang sudah dilatih...
# Model berhasil dimuat!

# %%
key_value_test_new = dict()
for i in os.listdir(test_new_dir):
    key_value_test_new[i] = os.listdir(os.path.join(test_new_dir, i))

# %%
df_test_new = []
for key in key_value_test_new.keys():
    for j in key_value_test_new[key]:
        df_test_new.append([key, os.path.join(test_new_dir, key, j)])
df_test_new = pd.DataFrame(df_test_new, columns=('label', 'path'))
print("Total gambar test gabungan:", len(df_test_new))
# Out:
# Total gambar test gabungan: 826

# %%
def readimg(path):
    img = cv.imread(path)
    img = cv.resize(img, (224, 224))
    return img

# %%
import multiprocessing
with multiprocessing.Pool(4) as p:
    test_images_new = p.map(readimg, df_test_new['path'])

test_images_new = np.array(test_images_new, dtype='float')

# %%
le = preprocessing.LabelEncoder()
le.fit(df_test_new['label'])
test_labels_new = le.transform(df_test_new['label'])

# %%
print("\n Melakukan prediksi pada data test gabungan...")
predictions_new = model.predict(test_images_new)
predicted_labels_new = np.argmax(predictions_new, axis=1)
# Out:
#  Melakukan prediksi pada data test gabungan...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 312ms/step

# %%
accuracy = accuracy_score(test_labels_new, predicted_labels_new)
precision = precision_score(test_labels_new, predicted_labels_new, average='macro')
recall = recall_score(test_labels_new, predicted_labels_new, average='macro')
f1 = f1_score(test_labels_new, predicted_labels_new, average='macro')

# %%
print("\n=== HASIL EVALUASI DATA TEST GABUNGAN ===")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-Score : {f1:.4f}")
# Out:
# === HASIL EVALUASI DATA TEST GABUNGAN ===
# Accuracy : 0.8632
# Precision: 0.8769
# Recall   : 0.8639
# F1-Score : 0.8628

# %%
target_class_names = le.classes_
print("\nClassification Report:")
print(classification_report(test_labels_new, predicted_labels_new, target_names=target_class_names, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9691    1.0000    0.9843        94
#            1     0.9538    0.8857    0.9185        70
#            2     0.9036    0.8721    0.8876        86
#            3     0.8144    0.9634    0.8827        82
#            4     0.8916    0.8810    0.8862        84
#            5     0.9744    0.9500    0.9620        80
#            6     0.9048    0.7703    0.8321        74
#            7     0.8657    0.6591    0.7484        88
#            8     0.8551    0.6705    0.7516        88
#            9     0.6371    0.9875    0.7745        80
#
#     accuracy                         0.8632       826
#    macro avg     0.8769    0.8639    0.8628       826
# weighted avg     0.8772    0.8632    0.8626       826

# %%
plt.figure(figsize=(7,7))
cm = confusion_matrix(test_labels_new, predicted_labels_new)
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g',
            xticklabels=target_class_names,
            yticklabels=target_class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Data Test Gabungan")
plt.show()

# %%
import random

correct_idx = np.where(predicted_labels_new == test_labels_new)[0]
incorrect_idx = np.where(predicted_labels_new != test_labels_new)[0]

def show_images(indices, title):
    plt.figure(figsize=(14, 6))
    for i, idx in enumerate(random.sample(list(indices), min(10, len(indices)))):
        plt.subplot(2, 5, i + 1)
        img = cv.cvtColor(test_images_new[idx].astype('uint8'), cv.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.title(f"Pred: {target_class_names[predicted_labels_new[idx]]}\nTrue: {target_class_names[test_labels_new[idx]]}")
        plt.axis('off')
    plt.suptitle(title, fontsize=16)
    plt.show()

show_images(correct_idx, "Contoh Prediksi Benar (Data Test Gabungan)")
show_images(incorrect_idx, "Contoh Prediksi Salah (Data Test Gabungan)")
